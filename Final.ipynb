# %% [markdown]
# # Identifying Medical Diagnoses and Treatable Diseases by Image-Based Deep Learning
# #### Written and Coded by: Joshua Ko
# #### Last updated: 11/30/2023
# ___

# %% [markdown]
# This notebook serves to find the best model that will yield the best metrics in predicting patients who have pneumonia, as well as whether the infection is bacterial or viral. The best model can then be stored in a separate file for future use. Unfortunately, image classification is very demanding; these codes were run on a HP Spectre x360 with an i7-10510U CPU. A more accurate model may be found by using better specs and performing a grid search to find optimal hyperparameters.

# %% [markdown]
# ___
# Import some of the necessary libraries

# %%
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os

# %% [markdown]
# ## Unbalanced vs. balanced datasets
# When observing the file holding the training images, there is a large imbalance between the `NORMAL` and `PNEUMONIA` class. It is important to balance these classes so that our model is not biased towards one class. In order to balance the dataset, we can scrape more images, or create more images using image augmentation (we will go with the image augmentation approach). However, just running the image through `.ImageDataGenerator()` doesn't store the augmented image. We can create a separate folder of images that stores the augmented images as well as the original, thereby increasing our minority class (in this case, our `NORMAL` class). We can create a balanced dataframe contain the paths of the images (both original and augmented). Then import those images by using `flow_from_dataframe`.

# %%
import pandas as pd
import shutil # high-level operation on a file like a copy, create, and remote operation on the file
from tqdm import tqdm # progress bar for loops and iterations

# %% [markdown]
# The following functions were provided by [Gerry P](https://stackoverflow.com/users/10798917/gerry-p) from this [stackflow question](https://stackoverflow.com/questions/73971025/how-to-do-data-augmentation-and-save-it-to-another-folder).

# %%
def make_dataframe(sdir):
    # sdir is the directory when the class subdirectories are stored
    filepaths=[]
    labels=[]
    classlist=sorted(os.listdir(sdir) )
    for klass in classlist:
        classpath=os.path.join(sdir, klass)
        if os.path.isdir(classpath):
            flist=sorted(os.listdir(classpath))
            desc=f'{klass:25s}'
            for f in tqdm(flist, ncols=130,desc=desc, unit='files', colour='blue'):
                fpath=os.path.join(classpath,f)
                filepaths.append(fpath)
                labels.append(klass)
    Fseries=pd.Series(filepaths, name='filepaths')
    Lseries=pd.Series(labels, name='labels')
    df=pd.concat([Fseries, Lseries], axis=1)
    # return a dataframe with columns filepaths, labels
    return df

def make_and_store_images(df, augdir, n,  img_size,  color_mode='rgb', save_prefix='aug-',save_format='jpg'):
    # augdir is the full path where augmented images will be stored
    # n is the number of augmented images that will be created for each class that has less than n image samples
    # img_size is a tupple(height,width) that specifies the size of the augmented images
    # color_mode is 'rgb by default'
    # save_prefix is the prefix augmented images are identified with by default it is 'aug-'
    # save_format is the format augmented images will be save in, by default it is 'jpg'
    # see documentation of ImageDataGenerator at https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator for details
    df=df.copy()
    if os.path.isdir(augdir):# start with an empty directory
        shutil.rmtree(augdir)
    os.mkdir(augdir)  # if directory does not exist create it
    for label in df['labels'].unique():
        classpath=os.path.join(augdir,label)
        os.mkdir(classpath) # make class directories within aug directory
    # create and store the augmented images
    total=0
    # in ImageDateGenerator select the types of augmentation you desire below are some examples
    gen=image.ImageDataGenerator(horizontal_flip=True,
                                 rotation_range=20,
                                 width_shift_range=.1,
                                 height_shift_range=.1)
    groups=df.groupby('labels') # group by class
    for label in df['labels'].unique():  # for every class
        classdir=os.path.join(augdir, label)
        group=groups.get_group(label)  # a dataframe holding only rows with the specified label
        sample_count=len(group)   # determine how many samples there are in this class
        if sample_count< n: # if the class has less than target number of images
            aug_img_count=0
            delta=n - sample_count  # number of augmented images to create
            msg='{0:40s} for class {1:^30s} creating {2:^5s} augmented images'.format(' ', label, str(delta))
            print(msg, '\r', end='') # prints over on the same line
            aug_gen=gen.flow_from_dataframe( group,  x_col='filepaths', y_col=None, target_size=img_size,
                                            class_mode=None, batch_size=1, shuffle=False,
                                            save_to_dir=classdir, save_prefix=save_prefix, color_mode=color_mode,
                                            save_format=save_format, seed=42)
            while aug_img_count<delta:
                images=next(aug_gen)
                aug_img_count += len(images)
            total +=aug_img_count
    print('Total Augmented images created= ', total)

# %%
# run the make_dataframe() function on the train set to see how many images to augment
train_directory = 'Data/chest_xray/train/'
df = make_dataframe(train_directory)

print(
    df.head(), # inspect the dataframe so that it is properly integrated into the dataframe
    '\nlength of dataframe is ',len(df)
)
# Out:
# NORMAL                   : 100%|███████████████████████████████████████████████████████| 1349/1349 [00:00<00:00, 337234.24files/s]
# PNEUMONIA                : 100%|███████████████████████████████████████████████████████| 3883/3883 [00:00<00:00, 352895.55files/s]
#                                            filepaths  labels
# 0  Data/chest_xray/train/NORMAL\NORMAL-1003233-00...  NORMAL
# 1  Data/chest_xray/train/NORMAL\NORMAL-1012843-00...  NORMAL
# 2  Data/chest_xray/train/NORMAL\NORMAL-1014768-00...  NORMAL
# 3  Data/chest_xray/train/NORMAL\NORMAL-1023731-00...  NORMAL
# 4  Data/chest_xray/train/NORMAL\NORMAL-1029510-00...  NORMAL
# length of dataframe is  5232

# %% [markdown]
# Seems like there are 2534 more images labeled `PNEUMONIA`; we must augment that many `NORMAL` images to balance the classes. However over augmenting the images may lead to overfitting, therefore we will augment the minority class until we reach a total of `2500` `NORMAL` images and undersample the majority.

# %%
augment_dir='Data\Augmented' # A newly created folder titled `Augmented` holds the augmented image.

make_and_store_images(df, augment_dir, n=2500, img_size=(256,256), color_mode='rgb', save_prefix='aug-',save_format='jpg')
# Out:
# Found 1349 validated image filenames.    for class             NORMAL             creating 1151  augmented images
# Total Augmented images created=  1151

# %%
aug_df = make_dataframe(augment_dir) # using the same function to create a dataframe with labels and file paths
len(aug_df) # check to see if all the images are stored in the dataframe
# Out:
# NORMAL                   : 100%|███████████████████████████████████████████████████████| 1151/1151 [00:00<00:00, 383542.06files/s]
# PNEUMONIA                : 0files [00:00, ?files/s]
# 1151

# %% [markdown]
# An undersampled dataframe will store `2500` filepaths of the majority class. Then `df` will be concatenated with rows only containing the `NORMAL` class along with `aug_df`.

# %%
# undersampling the number of images labeled 'pneumonia'
under_df = df[df['filepaths'].str.contains('PNEUMONIA')].sample(n=2500, random_state=42, ignore_index=False)

print(
    under_df.head(),
    '\n',
    under_df['labels'].value_counts()
)
# Out:
#                                               filepaths     labels
# 2693  Data/chest_xray/train/PNEUMONIA\BACTERIA-56283...  PNEUMONIA
# 3986  Data/chest_xray/train/PNEUMONIA\VIRUS-1623574-...  PNEUMONIA
# 4947  Data/chest_xray/train/PNEUMONIA\VIRUS-8054264-...  PNEUMONIA
# 4964  Data/chest_xray/train/PNEUMONIA\VIRUS-8161653-...  PNEUMONIA
# 3161  Data/chest_xray/train/PNEUMONIA\BACTERIA-74378...  PNEUMONIA
#  labels
# PNEUMONIA    2500
# Name: count, dtype: int64

# %%
# concatenate the dataframes
balanced_df = pd.concat([under_df, df[df['filepaths'].str.contains('NORMAL')], aug_df], ignore_index=True)
balanced_df['labels'].value_counts() # check to see if classes are balanced
# Out:
# labels
# PNEUMONIA    2500
# NORMAL       2500
# Name: count, dtype: int64

# %% [markdown]
# Upon further inspection of the dataframe, the features of the dataframe are organized according to its labels (`NORMAL` or `PNEUMONIA`). Although this may not affect the `train_generator` as `shuffle=True`, this may cause the validation set to be highly biased towards one class. Therefore we will shuffle the dataframe.

# %%
from sklearn.utils import shuffle

balanced_df = shuffle(balanced_df, random_state=42)

# %% [markdown]
# ## Importing images from dataframe
# Now that the classes are balanced, we can import the images using `.flow_froma_dataframe`. To import, batch, and standardize the images, the class, `ImageDataGenerator()` is used. To check that the images are properly imported, we can use matplotlib's `.imshow()`.
# <br>
# <br>First, we will define the target and batch size:

# %%
target_size = (256, 256) # a larger targe_size can be used if the computer has the specs for it
batch_size = 32 # a batch_size of 128 or more will need a high performing GPU

# %%
train_datagen = image.ImageDataGenerator(rescale=1./255, # standardizes color pixels that have a maximum value of 255
                                         validation_split=0.2 # allocates 20% of the data as the validation set
                                        )

# %%
# import the balanced imageset from balanced_df using .flow_from_dataframe()
balanced_train_generator = train_datagen.flow_from_dataframe(
    balanced_df,
    x_col='filepaths',
    y_col='labels',
    target_size=target_size,
    batch_size=batch_size,
    class_mode='binary',
    subset='training',
    shuffle=True,
    seed=42
)

balanced_validation_generator = train_datagen.flow_from_dataframe(
    balanced_df,
    x_col='filepaths',
    y_col='labels',
    target_size=target_size,
    batch_size=batch_size,
    class_mode='binary',
    subset='validation',
    shuffle=False
)
# Out:
# Found 4000 validated image filenames belonging to 2 classes.
# Found 1000 validated image filenames belonging to 2 classes.

# %%
# check if the images are properly imported
fig, ax = plt.subplots(ncols = 4, figsize=(20,20))
for idx, img in enumerate(balanced_train_generator[0][0][:4]):
    ax[idx].imshow(img)
    ax[idx].title.set_text(balanced_train_generator[0][1][idx])

# %% [markdown]
# According to the images shown, `NORMAL` = `0` and `PNEUMONIA` = `1`.

# %% [markdown]
# ## Creating the neural network

# %% [markdown]
# We will be making a `Sequential()` model to help us differentiate between the two classes. In order to determine the complexity of the neural network, we should start with a simple model and integrate more layers according to the metrics of the model.  We can observe the metrics of each epoch by importing from `keras.metrics`.

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten
from keras.metrics import MeanSquaredError, TruePositives, FalsePositives, TrueNegatives, FalseNegatives, Precision, Recall, BinaryAccuracy, AUC

# %%
# metrics used to observe the improvement or lack there of per epoch
metrics = [
    'acc',
    MeanSquaredError(name='Brier score'),
    TruePositives(name='tp'),
    FalsePositives(name='fp'),
    TrueNegatives(name='tn'),
    FalseNegatives(name='fn'),
    Precision(name='precision'),
    Recall(name='recall'),
    AUC(name='auc'),
    AUC(name='prc', curve='PR') # precision-recall curve
]

# %% [markdown]
# A simple neural network with one hidden layer will be constructed and tested first, as a more complex network may lead to overfitting. If the metrics are too poor, we can add different layers to the network.

# %%
# fitting the balanced dataset
simple_model = Sequential()

simple_model.add(Flatten(input_shape=(256,256,3)))
# input layer that flattens the images into a 1-D array

simple_model.add(Dense(64, activation='relu'))
# A hidden layer with 64 nodes

simple_model.add(Dense(1, activation='sigmoid'))
# Output layer yielding only 1 value

simple_model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=metrics)

balanced_history = simple_model.fit(balanced_train_generator,
          steps_per_epoch=int(np.ceil(4000/batch_size)),
          epochs=30,
          validation_data=balanced_validation_generator,
          validation_steps=int(np.ceil(1000/batch_size)))
# Out:
# Epoch 1/30
# 125/125 [==============================] - 37s 286ms/step - loss: 6.8372 - acc: 0.5058 - Brier score: 0.3028 - tp: 1673.0000 - fp: 1650.0000 - tn: 350.0000 - fn: 327.0000 - precision: 0.5035 - recall: 0.8365 - auc: 0.5036 - prc: 0.5020 - val_loss: 0.6932 - val_acc: 0.5000 - val_Brier score: 0.2500 - val_tp: 500.0000 - val_fp: 500.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.5000 - val_prc: 0.5000
# Epoch 2/30
# 125/125 [==============================] - 31s 245ms/step - loss: 0.6932 - acc: 0.5000 - Brier score: 0.2500 - tp: 2000.0000 - fp: 2000.0000 - tn: 0.0000e+00 - fn: 0.0000e+00 - precision: 0.5000 - recall: 1.0000 - auc: 0.5000 - prc: 0.5000 - val_loss: 0.6932 - val_acc: 0.5000 - val_Brier score: 0.2500 - val_tp: 500.0000 - val_fp: 500.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.5000 - val_prc: 0.5000
# Epoch 3/30
# 125/125 [==============================] - 30s 243ms/step - loss: 0.6932 - acc: 0.5000 - Brier score: 0.2500 - tp: 2000.0000 - fp: 2000.0000 - tn: 0.0000e+00 - fn: 0.0000e+00 - precision: 0.5000 - recall: 1.0000 - auc: 0.4945 - prc: 0.4971 - val_loss: 0.6932 - val_acc: 0.5000 - val_Brier score: 0.2500 - val_tp: 500.0000 - val_fp: 500.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.5000 - val_prc: 0.5000
# Epoch 4/30
# 125/125 [==============================] - 30s 243ms/step - loss: 0.6932 - acc: 0.5000 - Brier score: 0.2500 - tp: 2000.0000 - fp: 2000.0000 - tn: 0.0000e+00 - fn: 0.0000e+00 - precision: 0.5000 - recall: 1.0000 - auc: 0.4925 - prc: 0.4925 - val_loss: 0.6932 - val_acc: 0.5000 - val_Brier score: 0.2500 - val_tp: 500.0000 - val_fp: 500.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.5000 - val_prc: 0.5000
# Epoch 5/30
# 125/125 [==============================] - 31s 244ms/step - loss: 0.6932 - acc: 0.5000 - Brier score: 0.2500 - tp: 2000.0000 - fp: 2000.0000 - tn: 0.0000e+00 - fn: 0.0000e+00 - precision: 0.5000 - recall: 1.0000 - auc: 0.5000 - prc: 0.5000 - val_loss: 0.6932 - val_acc: 0.5000 - val_Brier score: 0.2500 - val_tp: 500.0000 - val_fp: 500.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.5000 - val_prc: 0.5000
# Epoch 6/30
# 125/125 [==============================] - 31s 245ms/step - loss: 0.6932 - acc: 0.4945 - Brier score: 0.2500 - tp: 1605.0000 - fp: 1627.0000 - tn: 373.0000 - fn: 395.0000 - precision: 0.4966 - recall: 0.8025 - auc: 0.5000 - prc: 0.5000 - val_loss: 0.6932 - val_acc: 0.5000 - val_Brier score: 0.2500 - val_tp: 500.0000 - val_fp: 500.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.5000 - val_prc: 0.5000
# Epoch 7/30
# 125/125 [==============================] - 30s 243ms/step - loss: 0.6932 - acc: 0.5000 - Brier score: 0.2500 - tp: 2000.0000 - fp: 2000.0000 - tn: 0.0000e+00 - fn: 0.0000e+00 - precision: 0.5000 - recall: 1.0000 - auc: 0.5000 - prc: 0.5000 - val_loss: 0.6932 - val_acc: 0.5000 - val_Brier score: 0.2500 - val_tp: 500.0000 - val_fp: 500.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.5000 - val_prc: 0.5000
# Epoch 8/30
# 125/125 [==============================] - 30s 244ms/step - loss: 0.6932 - acc: 0.4880 - Brier score: 0.2500 - tp: 1128.0000 - fp: 1176.0000 - tn: 824.0000 - fn: 872.0000 - precision: 0.4896 - recall: 0.5640 - auc: 0.5000 - prc: 0.5000 - val_loss: 0.6931 - val_acc: 0.5000 - val_Brier score: 0.2500 - val_tp: 500.0000 - val_fp: 500.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.5000 - val_prc: 0.5000
# Epoch 9/30
# 125/125 [==============================] - 31s 244ms/step - loss: 0.6932 - acc: 0.5000 - Brier score: 0.2500 - tp: 2000.0000 - fp: 2000.0000 - tn: 0.0000e+00 - fn: 0.0000e+00 - precision: 0.5000 - recall: 1.0000 - auc: 0.4925 - prc: 0.4905 - val_loss: 0.6931 - val_acc: 0.5000 - val_Brier score: 0.2500 - val_tp: 500.0000 - val_fp: 500.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.5000 - val_prc: 0.5000
# Epoch 10/30
# 125/125 [==============================] - 31s 245ms/step - loss: 0.6932 - acc: 0.4835 - Brier score: 0.2500 - tp: 1727.0000 - fp: 1793.0000 - tn: 207.0000 - fn: 273.0000 - precision: 0.4906 - recall: 0.8635 - auc: 0.5000 - prc: 0.5000 - val_loss: 0.6931 - val_acc: 0.5000 - val_Brier score: 0.2500 - val_tp: 500.0000 - val_fp: 500.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.5000 - val_prc: 0.5000
# Epoch 11/30
# 125/125 [==============================] - 31s 245ms/step - loss: 0.6932 - acc: 0.4900 - Brier score: 0.2500 - tp: 1484.0000 - fp: 1524.0000 - tn: 476.0000 - fn: 516.0000 - precision: 0.4934 - recall: 0.7420 - auc: 0.5000 - prc: 0.5000 - val_loss: 0.6931 - val_acc: 0.5000 - val_Brier score: 0.2500 - val_tp: 500.0000 - val_fp: 500.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.5000 - val_prc: 0.5000
# Epoch 12/30
# 125/125 [==============================] - 31s 244ms/step - loss: 0.6932 - acc: 0.4900 - Brier score: 0.2500 - tp: 1756.0000 - fp: 1796.0000 - tn: 204.0000 - fn: 244.0000 - precision: 0.4944 - recall: 0.8780 - auc: 0.5000 - prc: 0.5000 - val_loss: 0.6931 - val_acc: 0.5000 - val_Brier score: 0.2500 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 500.0000 - val_fn: 500.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5000 - val_prc: 0.5000
# Epoch 13/30
# 125/125 [==============================] - 31s 245ms/step - loss: 0.6932 - acc: 0.4925 - Brier score: 0.2500 - tp: 1425.0000 - fp: 1455.0000 - tn: 545.0000 - fn: 575.0000 - precision: 0.4948 - recall: 0.7125 - auc: 0.5000 - prc: 0.5000 - val_loss: 0.6931 - val_acc: 0.5000 - val_Brier score: 0.2500 - val_tp: 500.0000 - val_fp: 500.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.5000 - val_prc: 0.5000
# Epoch 14/30
# 125/125 [==============================] - 31s 246ms/step - loss: 0.6932 - acc: 0.4760 - Brier score: 0.2500 - tp: 1600.0000 - fp: 1696.0000 - tn: 304.0000 - fn: 400.0000 - precision: 0.4854 - recall: 0.8000 - auc: 0.5000 - prc: 0.5000 - val_loss: 0.6931 - val_acc: 0.5000 - val_Brier score: 0.2500 - val_tp: 500.0000 - val_fp: 500.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.5000 - val_prc: 0.5000
# Epoch 15/30
# 125/125 [==============================] - 30s 243ms/step - loss: 0.6932 - acc: 0.4875 - Brier score: 0.2500 - tp: 359.0000 - fp: 409.0000 - tn: 1591.0000 - fn: 1641.0000 - precision: 0.4674 - recall: 0.1795 - auc: 0.5000 - prc: 0.5000 - val_loss: 0.6931 - val_acc: 0.5000 - val_Brier score: 0.2500 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 500.0000 - val_fn: 500.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5000 - val_prc: 0.5000
# Epoch 16/30
# 125/125 [==============================] - 31s 245ms/step - loss: 0.6932 - acc: 0.4965 - Brier score: 0.2500 - tp: 1177.0000 - fp: 1191.0000 - tn: 809.0000 - fn: 823.0000 - precision: 0.4970 - recall: 0.5885 - auc: 0.5000 - prc: 0.5000 - val_loss: 0.6931 - val_acc: 0.5000 - val_Brier score: 0.2500 - val_tp: 500.0000 - val_fp: 500.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.5000 - val_prc: 0.5000
# Epoch 17/30
# 125/125 [==============================] - 31s 244ms/step - loss: 0.6932 - acc: 0.4895 - Brier score: 0.2500 - tp: 1579.0000 - fp: 1621.0000 - tn: 379.0000 - fn: 421.0000 - precision: 0.4934 - recall: 0.7895 - auc: 0.5000 - prc: 0.5000 - val_loss: 0.6931 - val_acc: 0.5000 - val_Brier score: 0.2500 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 500.0000 - val_fn: 500.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5000 - val_prc: 0.5000
# Epoch 18/30
# 125/125 [==============================] - 31s 245ms/step - loss: 0.6932 - acc: 0.5000 - Brier score: 0.2500 - tp: 0.0000e+00 - fp: 0.0000e+00 - tn: 2000.0000 - fn: 2000.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.5000 - prc: 0.5000 - val_loss: 0.6931 - val_acc: 0.5000 - val_Brier score: 0.2500 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 500.0000 - val_fn: 500.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5000 - val_prc: 0.5000
# Epoch 19/30
# 125/125 [==============================] - 31s 249ms/step - loss: 0.6932 - acc: 0.4980 - Brier score: 0.2500 - tp: 60.0000 - fp: 68.0000 - tn: 1932.0000 - fn: 1940.0000 - precision: 0.4688 - recall: 0.0300 - auc: 0.4880 - prc: 0.4917 - val_loss: 0.6931 - val_acc: 0.5000 - val_Brier score: 0.2500 - val_tp: 500.0000 - val_fp: 500.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.5000 - val_prc: 0.5000
# Epoch 20/30
# 125/125 [==============================] - 31s 244ms/step - loss: 0.6932 - acc: 0.4900 - Brier score: 0.2500 - tp: 972.0000 - fp: 1012.0000 - tn: 988.0000 - fn: 1028.0000 - precision: 0.4899 - recall: 0.4860 - auc: 0.5000 - prc: 0.5000 - val_loss: 0.6931 - val_acc: 0.5000 - val_Brier score: 0.2500 - val_tp: 500.0000 - val_fp: 500.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.5000 - val_prc: 0.5000
# Epoch 21/30
# 125/125 [==============================] - 30s 243ms/step - loss: 0.6932 - acc: 0.4920 - Brier score: 0.2500 - tp: 1088.0000 - fp: 1120.0000 - tn: 880.0000 - fn: 912.0000 - precision: 0.4928 - recall: 0.5440 - auc: 0.5000 - prc: 0.5000 - val_loss: 0.6931 - val_acc: 0.5000 - val_Brier score: 0.2500 - val_tp: 500.0000 - val_fp: 500.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.5000 - val_prc: 0.5000
# Epoch 22/30
# 125/125 [==============================] - 31s 244ms/step - loss: 0.6932 - acc: 0.4825 - Brier score: 0.2500 - tp: 1357.0000 - fp: 1427.0000 - tn: 573.0000 - fn: 643.0000 - precision: 0.4874 - recall: 0.6785 - auc: 0.5000 - prc: 0.5000 - val_loss: 0.6931 - val_acc: 0.5000 - val_Brier score: 0.2500 - val_tp: 500.0000 - val_fp: 500.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.5000 - val_prc: 0.5000
# Epoch 23/30
# 125/125 [==============================] - 30s 243ms/step - loss: 0.6932 - acc: 0.5000 - Brier score: 0.2500 - tp: 2000.0000 - fp: 2000.0000 - tn: 0.0000e+00 - fn: 0.0000e+00 - precision: 0.5000 - recall: 1.0000 - auc: 0.5000 - prc: 0.5000 - val_loss: 0.6931 - val_acc: 0.5000 - val_Brier score: 0.2500 - val_tp: 500.0000 - val_fp: 500.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.5000 - val_prc: 0.5000
# Epoch 24/30
# 125/125 [==============================] - 31s 244ms/step - loss: 0.6932 - acc: 0.4915 - Brier score: 0.2500 - tp: 287.0000 - fp: 321.0000 - tn: 1679.0000 - fn: 1713.0000 - precision: 0.4720 - recall: 0.1435 - auc: 0.5000 - prc: 0.5000 - val_loss: 0.6931 - val_acc: 0.5000 - val_Brier score: 0.2500 - val_tp: 500.0000 - val_fp: 500.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.5000 - val_prc: 0.5000
# Epoch 25/30
# 125/125 [==============================] - 74s 595ms/step - loss: 0.6932 - acc: 0.4880 - Brier score: 0.2500 - tp: 856.0000 - fp: 904.0000 - tn: 1096.0000 - fn: 1144.0000 - precision: 0.4864 - recall: 0.4280 - auc: 0.5000 - prc: 0.5000 - val_loss: 0.6931 - val_acc: 0.5000 - val_Brier score: 0.2500 - val_tp: 500.0000 - val_fp: 500.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.5000 - val_prc: 0.5000
# Epoch 26/30
# 125/125 [==============================] - 39s 315ms/step - loss: 0.6932 - acc: 0.4965 - Brier score: 0.2500 - tp: 313.0000 - fp: 327.0000 - tn: 1673.0000 - fn: 1687.0000 - precision: 0.4891 - recall: 0.1565 - auc: 0.5000 - prc: 0.5000 - val_loss: 0.6931 - val_acc: 0.5000 - val_Brier score: 0.2500 - val_tp: 500.0000 - val_fp: 500.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.5000 - val_prc: 0.5000
# Epoch 27/30
# 125/125 [==============================] - 33s 263ms/step - loss: 0.6932 - acc: 0.4870 - Brier score: 0.2500 - tp: 1494.0000 - fp: 1546.0000 - tn: 454.0000 - fn: 506.0000 - precision: 0.4914 - recall: 0.7470 - auc: 0.5000 - prc: 0.5000 - val_loss: 0.6931 - val_acc: 0.5000 - val_Brier score: 0.2500 - val_tp: 500.0000 - val_fp: 500.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.5000 - val_prc: 0.5000
# Epoch 28/30
# 125/125 [==============================] - 32s 257ms/step - loss: 0.6932 - acc: 0.4820 - Brier score: 0.2500 - tp: 924.0000 - fp: 996.0000 - tn: 1004.0000 - fn: 1076.0000 - precision: 0.4812 - recall: 0.4620 - auc: 0.5000 - prc: 0.5000 - val_loss: 0.6931 - val_acc: 0.5000 - val_Brier score: 0.2500 - val_tp: 500.0000 - val_fp: 500.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.5000 - val_prc: 0.5000
# Epoch 29/30
# 125/125 [==============================] - 32s 258ms/step - loss: 0.6932 - acc: 0.5000 - Brier score: 0.2500 - tp: 2000.0000 - fp: 2000.0000 - tn: 0.0000e+00 - fn: 0.0000e+00 - precision: 0.5000 - recall: 1.0000 - auc: 0.5000 - prc: 0.5000 - val_loss: 0.6931 - val_acc: 0.5000 - val_Brier score: 0.2500 - val_tp: 500.0000 - val_fp: 500.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.5000 - val_prc: 0.5000
# Epoch 30/30
# 125/125 [==============================] - 33s 261ms/step - loss: 0.6932 - acc: 0.4895 - Brier score: 0.2500 - tp: 1147.0000 - fp: 1189.0000 - tn: 811.0000 - fn: 853.0000 - precision: 0.4910 - recall: 0.5735 - auc: 0.5000 - prc: 0.5000 - val_loss: 0.6931 - val_acc: 0.5000 - val_Brier score: 0.2500 - val_tp: 500.0000 - val_fp: 500.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.5000 - val_prc: 0.5000

# %% [markdown]
# The simple neural network performed decently on the training set. However, the validation metrics are very inconsistent.
# <br>It also seems like the model may not learn in certain run throughs. For example, the accuracy, or `acc`, may remain stagnant at `0.500`. We can maybe prevent this and improve the model by adding a convolutional layer.
# <br>
# <br>This can be a long process. We can maximize our productivity by implementing `EarlyStopping()`. This will allow the model to stop learning by monitoring a specific metric (accuracy, mse, loss, etc). This will help prevent overfitting.

# %%
from keras.callbacks import EarlyStopping

early_stop = EarlyStopping(monitor='val_loss', patience=10, mode='auto', restore_best_weights=False)
# restore_best_weights can be set to true if you wish to store each model. This can be costly in terms of memory

# %%
# balanced dataset fitted in a cnn
cnn_model = Sequential()

cnn_model.add(Conv2D(64, kernel_size=(3,3), activation='relu',input_shape=(256,256,3)))
cnn_model.add(MaxPooling2D(2,2))
# Conv2D is a 2-D filter that slides through the matrix and multiplies the corresponding values
# MaxPooling2D strides through the newly created matrix and takes the maximum value within a 2x2 range

cnn_model.add(Flatten())

cnn_model.add(Dense(128, activation='relu'))
cnn_model.add(Dense(1, activation='sigmoid'))

cnn_model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=metrics)


cnn_history = cnn_model.fit(balanced_train_generator,
          steps_per_epoch=int(np.ceil(4000/batch_size)),
          epochs=30,
          validation_data=balanced_validation_generator,
          validation_steps=int(np.ceil(1000/batch_size)),
          callbacks=[early_stop])
# Out:
# Epoch 1/30
# 125/125 [==============================] - 40s 266ms/step - loss: 1.6735 - acc: 0.8315 - Brier score: 0.1635 - tp: 2087.0000 - fp: 761.0000 - tn: 1739.0000 - fn: 413.0000 - precision: 0.7328 - recall: 0.8348 - auc: 0.8341 - prc: 0.8241 - val_loss: 0.1391 - val_acc: 0.9490 - val_Brier score: 0.0372 - val_tp: 478.0000 - val_fp: 29.0000 - val_tn: 471.0000 - val_fn: 22.0000 - val_precision: 0.9428 - val_recall: 0.9560 - val_auc: 0.9891 - val_prc: 0.9914
# Epoch 2/30
# 125/125 [==============================] - 33s 260ms/step - loss: 0.0981 - acc: 0.9647 - Brier score: 0.0257 - tp: 1907.0000 - fp: 48.0000 - tn: 1952.0000 - fn: 93.0000 - precision: 0.9754 - recall: 0.9535 - auc: 0.9939 - prc: 0.9946 - val_loss: 0.1844 - val_acc: 0.9360 - val_Brier score: 0.0516 - val_tp: 496.0000 - val_fp: 60.0000 - val_tn: 440.0000 - val_fn: 4.0000 - val_precision: 0.8921 - val_recall: 0.9920 - val_auc: 0.9905 - val_prc: 0.9910
# Epoch 3/30
# 125/125 [==============================] - 33s 261ms/step - loss: 0.0335 - acc: 0.9925 - Brier score: 0.0075 - tp: 1980.0000 - fp: 10.0000 - tn: 1990.0000 - fn: 20.0000 - precision: 0.9950 - recall: 0.9900 - auc: 0.9996 - prc: 0.9996 - val_loss: 0.0898 - val_acc: 0.9730 - val_Brier score: 0.0214 - val_tp: 480.0000 - val_fp: 7.0000 - val_tn: 493.0000 - val_fn: 20.0000 - val_precision: 0.9856 - val_recall: 0.9600 - val_auc: 0.9928 - val_prc: 0.9932
# Epoch 4/30
# 125/125 [==============================] - 33s 260ms/step - loss: 0.0122 - acc: 0.9977 - Brier score: 0.0022 - tp: 1994.0000 - fp: 3.0000 - tn: 1997.0000 - fn: 6.0000 - precision: 0.9985 - recall: 0.9970 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.1004 - val_acc: 0.9700 - val_Brier score: 0.0232 - val_tp: 478.0000 - val_fp: 8.0000 - val_tn: 492.0000 - val_fn: 22.0000 - val_precision: 0.9835 - val_recall: 0.9560 - val_auc: 0.9930 - val_prc: 0.9932
# Epoch 5/30
# 125/125 [==============================] - 32s 258ms/step - loss: 0.0033 - acc: 1.0000 - Brier score: 2.0145e-04 - tp: 2000.0000 - fp: 0.0000e+00 - tn: 2000.0000 - fn: 0.0000e+00 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0991 - val_acc: 0.9770 - val_Brier score: 0.0198 - val_tp: 488.0000 - val_fp: 11.0000 - val_tn: 489.0000 - val_fn: 12.0000 - val_precision: 0.9780 - val_recall: 0.9760 - val_auc: 0.9915 - val_prc: 0.9897
# Epoch 6/30
# 125/125 [==============================] - 32s 258ms/step - loss: 0.0011 - acc: 1.0000 - Brier score: 2.4653e-05 - tp: 2000.0000 - fp: 0.0000e+00 - tn: 2000.0000 - fn: 0.0000e+00 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.1105 - val_acc: 0.9700 - val_Brier score: 0.0231 - val_tp: 477.0000 - val_fp: 7.0000 - val_tn: 493.0000 - val_fn: 23.0000 - val_precision: 0.9855 - val_recall: 0.9540 - val_auc: 0.9930 - val_prc: 0.9935
# Epoch 7/30
# 125/125 [==============================] - 32s 258ms/step - loss: 6.6058e-04 - acc: 1.0000 - Brier score: 7.5268e-06 - tp: 2000.0000 - fp: 0.0000e+00 - tn: 2000.0000 - fn: 0.0000e+00 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.1003 - val_acc: 0.9770 - val_Brier score: 0.0184 - val_tp: 488.0000 - val_fp: 11.0000 - val_tn: 489.0000 - val_fn: 12.0000 - val_precision: 0.9780 - val_recall: 0.9760 - val_auc: 0.9921 - val_prc: 0.9903
# Epoch 8/30
# 125/125 [==============================] - 32s 258ms/step - loss: 4.1854e-04 - acc: 1.0000 - Brier score: 3.3153e-06 - tp: 2000.0000 - fp: 0.0000e+00 - tn: 2000.0000 - fn: 0.0000e+00 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.1038 - val_acc: 0.9760 - val_Brier score: 0.0192 - val_tp: 488.0000 - val_fp: 12.0000 - val_tn: 488.0000 - val_fn: 12.0000 - val_precision: 0.9760 - val_recall: 0.9760 - val_auc: 0.9920 - val_prc: 0.9902
# Epoch 9/30
# 125/125 [==============================] - 33s 261ms/step - loss: 2.7763e-04 - acc: 1.0000 - Brier score: 8.8762e-07 - tp: 2000.0000 - fp: 0.0000e+00 - tn: 2000.0000 - fn: 0.0000e+00 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.1023 - val_acc: 0.9780 - val_Brier score: 0.0184 - val_tp: 488.0000 - val_fp: 10.0000 - val_tn: 490.0000 - val_fn: 12.0000 - val_precision: 0.9799 - val_recall: 0.9760 - val_auc: 0.9923 - val_prc: 0.9904
# Epoch 10/30
# 125/125 [==============================] - 31s 245ms/step - loss: 1.9006e-04 - acc: 1.0000 - Brier score: 3.8137e-07 - tp: 2000.0000 - fp: 0.0000e+00 - tn: 2000.0000 - fn: 0.0000e+00 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.1119 - val_acc: 0.9750 - val_Brier score: 0.0207 - val_tp: 483.0000 - val_fp: 8.0000 - val_tn: 492.0000 - val_fn: 17.0000 - val_precision: 0.9837 - val_recall: 0.9660 - val_auc: 0.9924 - val_prc: 0.9919
# Epoch 11/30
# 125/125 [==============================] - 31s 245ms/step - loss: 1.4848e-04 - acc: 1.0000 - Brier score: 2.3891e-07 - tp: 2000.0000 - fp: 0.0000e+00 - tn: 2000.0000 - fn: 0.0000e+00 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.1115 - val_acc: 0.9730 - val_Brier score: 0.0206 - val_tp: 480.0000 - val_fp: 7.0000 - val_tn: 493.0000 - val_fn: 20.0000 - val_precision: 0.9856 - val_recall: 0.9600 - val_auc: 0.9925 - val_prc: 0.9920
# Epoch 12/30
# 125/125 [==============================] - 31s 244ms/step - loss: 1.1867e-04 - acc: 1.0000 - Brier score: 1.5819e-07 - tp: 2000.0000 - fp: 0.0000e+00 - tn: 2000.0000 - fn: 0.0000e+00 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.1051 - val_acc: 0.9770 - val_Brier score: 0.0184 - val_tp: 487.0000 - val_fp: 10.0000 - val_tn: 490.0000 - val_fn: 13.0000 - val_precision: 0.9799 - val_recall: 0.9740 - val_auc: 0.9924 - val_prc: 0.9905
# Epoch 13/30
# 125/125 [==============================] - 31s 245ms/step - loss: 1.0203e-04 - acc: 1.0000 - Brier score: 1.2496e-07 - tp: 2000.0000 - fp: 0.0000e+00 - tn: 2000.0000 - fn: 0.0000e+00 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.1043 - val_acc: 0.9780 - val_Brier score: 0.0180 - val_tp: 488.0000 - val_fp: 10.0000 - val_tn: 490.0000 - val_fn: 12.0000 - val_precision: 0.9799 - val_recall: 0.9760 - val_auc: 0.9924 - val_prc: 0.9906

# %% [markdown]
# It performed significantly better than the simple. We will observe how well the `cnn_model` performed by plotting the changes of the metrics as the epoch progresses.

# %%
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
# a list of different colors to help discern between metrics of two models

def plot_metrics(history_1, history_2, legend1='Unbalanced Train', legend2='Unbalanced Val', legend3='Balanced Train', legend4='Balanced Val'):
    # history_1 and history_2 are the two different histories that will be compared

    fig, axs = plt.subplots(3,2, figsize=(15, 10), dpi=100)
    axs = axs.ravel()
    # enumerates the axes going from left to right across the rows from the top row down to the bottom row

    metrics = ['acc','loss', 'auc', 'prc', 'precision', 'recall']
    # list of metrics so we can easily observe the changes

    for n, metric in enumerate(metrics): # loops through list
        name = metric.capitalize()
        # capitalizes the strings in the list (metrics) so we can use it to title the graphs

        axs[n].plot(history_1.epoch, history_1.history[metric], color=colors[0], label=legend1)
        axs[n].plot(history_1.epoch, history_1.history['val_'+metric], color=colors[0], linestyle='--', label=legend2)
        # creates a plot for the corresponding metric with a separate color to help discern from the balanced_history
        # the linestyle will help separate the validation metric with the train metric

        axs[n].plot(history_2.epoch, history_2.history[metric], color=colors[1], label=legend3)
        axs[n].plot(history_2.epoch, history_2.history['val_'+metric], color=colors[1], linestyle='--', label=legend4)

        axs[n].set_xlabel('Epoch')
        axs[n].set_ylabel(name)
        axs[n].set_title('Training and validation {}'.format(metric))

        if metric == 'loss':
            axs[n].legend(loc='upper right')
            axs[n].set_ylim(0, 1.0)
        # since the 'loss' in earlier epochs is huge, we can limit the y axis so we can observe smaller changes

        else:
            axs[n].legend(loc='lower right')

    plt.tight_layout()

# %%
# we are comparing the result of the addition of the convolutional layer and the simple model
plot_metrics(cnn_history, balanced_history, legend1='CNN Train', legend2='CNN Val', legend3='Simple Train', legend4='Simple Val')

# %% [markdown]
# Adding the convolutional layer dramatically improved the model, despite a slight overfitting for the balanced dataset. The plots also seem to plateau with higher epoch, therefore a higher epoch most likely would not alter the metrics between the train and validation sets. However, the metrics are relatively high (above 90%) and we can run the test set and create our predictions.

# %% [markdown]
# ## Preparing the test imageset and making predictions
# Again, we can use `.ImageDataGenerator()` to import our test set from the directory we defined above (`test_directory`). We will run the test set through `cnn_model` and observe the performance by observing the confusion matrix.

# %%
# importing the test imageset
test_directory = 'Data/chest_xray/test/'

test_datagen = image.ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    test_directory,
    target_size=target_size,
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False
)
# Out:
# Found 624 images belonging to 2 classes.

# %%
assert test_generator[0][0].shape == (32, 256, 256, 3) # check if the test set is properly imported

# %%
def predict(test_generator, model):
# test_generator holds the images imported from the directory
# model is the model we are running the test images through to make our prediction

    y_hat = model.predict(test_generator, batch_size=batch_size, steps=len(test_generator))
    # the y_hat is a 1-D array with decimals
    y_hat = list(np.rint(y_hat.reshape(624,)))
    # rounds the y_hat to its nearest integer and converts the array to a list
    return y_hat

# %%
# make predictions by running the function with proper inputs
y_hat = predict(test_generator, cnn_model)
# Out:
# 20/20 [==============================] - 5s 244ms/step

# %% [markdown]
# Once the predictions are stored, we can plot a confusion matrix to see how well the models performs. Before feeding the test labels and predictions into `confusion_matrix()`, the labels in the test set needs to be combined into one list or array, instead of batches.

# %%
# converting the labels to a list so we can run it through confusion_matrix()
test_labels = []

for x in range(0, len(test_generator)):
    test_labels.extend(np.array(test_generator[x][1]))

print('0 occurences: ', test_labels.count(0))
print('1 occurences: ', test_labels.count(1))
# Out:
# 0 occurences:  234
# 1 occurences:  390

# %% [markdown]
# There are `390` patients who have pneumonia and `234` who do not.

# %%
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix

def cf_matrix(y_hat):
#y_hat is the predictions we have made using the predict() function
    cm = confusion_matrix(test_labels, y_hat)

    disp = ConfusionMatrixDisplay(confusion_matrix=cm)

    disp.plot(cmap=plt.cm.Blues)
    plt.show()

# %%
#confusion matrix of values predicted by the convolutional layer
cf_matrix(y_hat)

# %% [markdown]
# We can also use the metrics from `sklearn.metrics` to calculate our scores:

# %%
from sklearn.metrics import precision_score, recall_score, accuracy_score, f1_score

def print_metrics(y_test, y_hat):
    print("Precision Score: {}".format(precision_score(y_test, y_hat)))
    print("Recall Score: {}".format(recall_score(y_test, y_hat)))
    print("Accuracy Score: {}".format(accuracy_score(y_test, y_hat)))
    print("F1 Score: {}".format(f1_score(y_test, y_hat)))

# %%
# unbalanced metrics
print_metrics(test_labels, y_hat)
# Out:
# Precision Score: 0.803347280334728
# Recall Score: 0.9846153846153847
# Accuracy Score: 0.8397435897435898
# F1 Score: 0.8847926267281107

# %% [markdown]
# The precision and accuracy leaves a lot to be desired. However, the recall score is high meaning that the model does a good job minimizing the false negative. This is a preferred metric over precision because a model with a high false negative will be harmful to both the patient and the hospital. Results may vary as these codes are repeatedly run, but should not vary too far from these values. We can address the overfitting of the model by incorporated some form of regression. While adding these changes to the model, we will monitor how the recall and accuracy scores change; preferably a relatively high recall and accuracy score while minimizing the overfitting.

# %% [markdown]
# ### Performing a ridge regression
# By performing a regression, we can fix the overfitting of the convolutional model. The ridge regression or l2 regularizer can be imported from `tensorflow.keras.regularizers` (a lasso regression or l1 regularizer can also be used).

# %%
from tensorflow.keras import regularizers

# %%
l2_model = Sequential()

l2_model.add(Conv2D(64, kernel_size=(3,3), activation='relu',input_shape=(256,256,3)))
l2_model.add(MaxPooling2D(2,2))

l2_model.add(Flatten())

l2_model.add(Dense(64, kernel_regularizer=regularizers.l2(0.0005), activation='relu'))
# the value for regularizers.l2() can range from 0 to infinity
l2_model.add(Dense(1, activation='sigmoid'))

l2_model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=metrics)

l2_history = l2_model.fit(balanced_train_generator,
          steps_per_epoch=int(np.ceil(4000/batch_size)),
          epochs=30,
          validation_data=balanced_validation_generator,
          validation_steps=int(np.ceil(1000/batch_size)),
          callbacks=[early_stop])
# Out:
# Epoch 1/30
# 125/125 [==============================] - 32s 248ms/step - loss: 3.1454 - acc: 0.8198 - Brier score: 0.1295 - tp: 2082.0000 - fp: 325.0000 - tn: 2175.0000 - fn: 418.0000 - precision: 0.8650 - recall: 0.8328 - auc: 0.8690 - prc: 0.8300 - val_loss: 0.5168 - val_acc: 0.8890 - val_Brier score: 0.0862 - val_tp: 492.0000 - val_fp: 103.0000 - val_tn: 397.0000 - val_fn: 8.0000 - val_precision: 0.8269 - val_recall: 0.9840 - val_auc: 0.9846 - val_prc: 0.9858
# Epoch 2/30
# 125/125 [==============================] - 31s 243ms/step - loss: 0.3699 - acc: 0.9420 - Brier score: 0.0489 - tp: 1853.0000 - fp: 85.0000 - tn: 1915.0000 - fn: 147.0000 - precision: 0.9561 - recall: 0.9265 - auc: 0.9843 - prc: 0.9864 - val_loss: 0.2965 - val_acc: 0.9570 - val_Brier score: 0.0363 - val_tp: 469.0000 - val_fp: 12.0000 - val_tn: 488.0000 - val_fn: 31.0000 - val_precision: 0.9751 - val_recall: 0.9380 - val_auc: 0.9925 - val_prc: 0.9928
# Epoch 3/30
# 125/125 [==============================] - 31s 244ms/step - loss: 0.2890 - acc: 0.9467 - Brier score: 0.0432 - tp: 1869.0000 - fp: 82.0000 - tn: 1918.0000 - fn: 131.0000 - precision: 0.9580 - recall: 0.9345 - auc: 0.9869 - prc: 0.9884 - val_loss: 0.2528 - val_acc: 0.9470 - val_Brier score: 0.0378 - val_tp: 456.0000 - val_fp: 9.0000 - val_tn: 491.0000 - val_fn: 44.0000 - val_precision: 0.9806 - val_recall: 0.9120 - val_auc: 0.9925 - val_prc: 0.9927
# Epoch 4/30
# 125/125 [==============================] - 31s 246ms/step - loss: 0.2342 - acc: 0.9517 - Brier score: 0.0360 - tp: 1884.0000 - fp: 77.0000 - tn: 1923.0000 - fn: 116.0000 - precision: 0.9607 - recall: 0.9420 - auc: 0.9911 - prc: 0.9920 - val_loss: 0.2078 - val_acc: 0.9660 - val_Brier score: 0.0309 - val_tp: 483.0000 - val_fp: 17.0000 - val_tn: 483.0000 - val_fn: 17.0000 - val_precision: 0.9660 - val_recall: 0.9660 - val_auc: 0.9932 - val_prc: 0.9931
# Epoch 5/30
# 125/125 [==============================] - 31s 247ms/step - loss: 0.1990 - acc: 0.9578 - Brier score: 0.0319 - tp: 1900.0000 - fp: 69.0000 - tn: 1931.0000 - fn: 100.0000 - precision: 0.9650 - recall: 0.9500 - auc: 0.9928 - prc: 0.9935 - val_loss: 0.2397 - val_acc: 0.9340 - val_Brier score: 0.0460 - val_tp: 492.0000 - val_fp: 58.0000 - val_tn: 442.0000 - val_fn: 8.0000 - val_precision: 0.8945 - val_recall: 0.9840 - val_auc: 0.9925 - val_prc: 0.9910
# Epoch 6/30
# 125/125 [==============================] - 31s 245ms/step - loss: 0.1896 - acc: 0.9613 - Brier score: 0.0318 - tp: 1908.0000 - fp: 63.0000 - tn: 1937.0000 - fn: 92.0000 - precision: 0.9680 - recall: 0.9540 - auc: 0.9928 - prc: 0.9936 - val_loss: 0.1747 - val_acc: 0.9640 - val_Brier score: 0.0286 - val_tp: 476.0000 - val_fp: 12.0000 - val_tn: 488.0000 - val_fn: 24.0000 - val_precision: 0.9754 - val_recall: 0.9520 - val_auc: 0.9946 - val_prc: 0.9944
# Epoch 7/30
# 125/125 [==============================] - 31s 244ms/step - loss: 0.1645 - acc: 0.9665 - Brier score: 0.0264 - tp: 1918.0000 - fp: 52.0000 - tn: 1948.0000 - fn: 82.0000 - precision: 0.9736 - recall: 0.9590 - auc: 0.9946 - prc: 0.9952 - val_loss: 0.1862 - val_acc: 0.9560 - val_Brier score: 0.0335 - val_tp: 491.0000 - val_fp: 35.0000 - val_tn: 465.0000 - val_fn: 9.0000 - val_precision: 0.9335 - val_recall: 0.9820 - val_auc: 0.9943 - val_prc: 0.9941
# Epoch 8/30
# 125/125 [==============================] - 31s 243ms/step - loss: 0.1606 - acc: 0.9697 - Brier score: 0.0255 - tp: 1923.0000 - fp: 44.0000 - tn: 1956.0000 - fn: 77.0000 - precision: 0.9776 - recall: 0.9615 - auc: 0.9952 - prc: 0.9957 - val_loss: 0.1657 - val_acc: 0.9690 - val_Brier score: 0.0273 - val_tp: 482.0000 - val_fp: 13.0000 - val_tn: 487.0000 - val_fn: 18.0000 - val_precision: 0.9737 - val_recall: 0.9640 - val_auc: 0.9938 - val_prc: 0.9939
# Epoch 9/30
# 125/125 [==============================] - 31s 244ms/step - loss: 0.1473 - acc: 0.9735 - Brier score: 0.0226 - tp: 1944.0000 - fp: 50.0000 - tn: 1950.0000 - fn: 56.0000 - precision: 0.9749 - recall: 0.9720 - auc: 0.9962 - prc: 0.9966 - val_loss: 0.1548 - val_acc: 0.9730 - val_Brier score: 0.0246 - val_tp: 489.0000 - val_fp: 16.0000 - val_tn: 484.0000 - val_fn: 11.0000 - val_precision: 0.9683 - val_recall: 0.9780 - val_auc: 0.9951 - val_prc: 0.9952
# Epoch 10/30
# 125/125 [==============================] - 31s 244ms/step - loss: 0.1551 - acc: 0.9707 - Brier score: 0.0243 - tp: 1928.0000 - fp: 45.0000 - tn: 1955.0000 - fn: 72.0000 - precision: 0.9772 - recall: 0.9640 - auc: 0.9956 - prc: 0.9962 - val_loss: 0.1716 - val_acc: 0.9560 - val_Brier score: 0.0312 - val_tp: 462.0000 - val_fp: 6.0000 - val_tn: 494.0000 - val_fn: 38.0000 - val_precision: 0.9872 - val_recall: 0.9240 - val_auc: 0.9948 - val_prc: 0.9949
# Epoch 11/30
# 125/125 [==============================] - 31s 244ms/step - loss: 0.1573 - acc: 0.9638 - Brier score: 0.0268 - tp: 1917.0000 - fp: 62.0000 - tn: 1938.0000 - fn: 83.0000 - precision: 0.9687 - recall: 0.9585 - auc: 0.9944 - prc: 0.9950 - val_loss: 0.1790 - val_acc: 0.9620 - val_Brier score: 0.0314 - val_tp: 474.0000 - val_fp: 12.0000 - val_tn: 488.0000 - val_fn: 26.0000 - val_precision: 0.9753 - val_recall: 0.9480 - val_auc: 0.9930 - val_prc: 0.9931
# Epoch 12/30
# 125/125 [==============================] - 31s 244ms/step - loss: 0.1387 - acc: 0.9737 - Brier score: 0.0207 - tp: 1933.0000 - fp: 38.0000 - tn: 1962.0000 - fn: 67.0000 - precision: 0.9807 - recall: 0.9665 - auc: 0.9969 - prc: 0.9971 - val_loss: 0.1617 - val_acc: 0.9630 - val_Brier score: 0.0288 - val_tp: 467.0000 - val_fp: 4.0000 - val_tn: 496.0000 - val_fn: 33.0000 - val_precision: 0.9915 - val_recall: 0.9340 - val_auc: 0.9959 - val_prc: 0.9959
# Epoch 13/30
# 125/125 [==============================] - 31s 246ms/step - loss: 0.1355 - acc: 0.9760 - Brier score: 0.0195 - tp: 1937.0000 - fp: 33.0000 - tn: 1967.0000 - fn: 63.0000 - precision: 0.9832 - recall: 0.9685 - auc: 0.9972 - prc: 0.9975 - val_loss: 0.2094 - val_acc: 0.9470 - val_Brier score: 0.0425 - val_tp: 496.0000 - val_fp: 49.0000 - val_tn: 451.0000 - val_fn: 4.0000 - val_precision: 0.9101 - val_recall: 0.9920 - val_auc: 0.9943 - val_prc: 0.9929
# Epoch 14/30
# 125/125 [==============================] - 31s 244ms/step - loss: 0.1359 - acc: 0.9753 - Brier score: 0.0204 - tp: 1938.0000 - fp: 37.0000 - tn: 1963.0000 - fn: 62.0000 - precision: 0.9813 - recall: 0.9690 - auc: 0.9972 - prc: 0.9973 - val_loss: 0.1651 - val_acc: 0.9660 - val_Brier score: 0.0268 - val_tp: 485.0000 - val_fp: 19.0000 - val_tn: 481.0000 - val_fn: 15.0000 - val_precision: 0.9623 - val_recall: 0.9700 - val_auc: 0.9941 - val_prc: 0.9943
# Epoch 15/30
# 125/125 [==============================] - 31s 243ms/step - loss: 0.1344 - acc: 0.9772 - Brier score: 0.0197 - tp: 1947.0000 - fp: 38.0000 - tn: 1962.0000 - fn: 53.0000 - precision: 0.9809 - recall: 0.9735 - auc: 0.9973 - prc: 0.9976 - val_loss: 0.1550 - val_acc: 0.9700 - val_Brier score: 0.0259 - val_tp: 479.0000 - val_fp: 9.0000 - val_tn: 491.0000 - val_fn: 21.0000 - val_precision: 0.9816 - val_recall: 0.9580 - val_auc: 0.9949 - val_prc: 0.9952
# Epoch 16/30
# 125/125 [==============================] - 31s 245ms/step - loss: 0.1174 - acc: 0.9820 - Brier score: 0.0149 - tp: 1957.0000 - fp: 29.0000 - tn: 1971.0000 - fn: 43.0000 - precision: 0.9854 - recall: 0.9785 - auc: 0.9985 - prc: 0.9987 - val_loss: 0.1578 - val_acc: 0.9580 - val_Brier score: 0.0281 - val_tp: 489.0000 - val_fp: 31.0000 - val_tn: 469.0000 - val_fn: 11.0000 - val_precision: 0.9404 - val_recall: 0.9780 - val_auc: 0.9941 - val_prc: 0.9930
# Epoch 17/30
# 125/125 [==============================] - 31s 243ms/step - loss: 0.1193 - acc: 0.9793 - Brier score: 0.0163 - tp: 1952.0000 - fp: 35.0000 - tn: 1965.0000 - fn: 48.0000 - precision: 0.9824 - recall: 0.9760 - auc: 0.9978 - prc: 0.9980 - val_loss: 0.1822 - val_acc: 0.9510 - val_Brier score: 0.0367 - val_tp: 458.0000 - val_fp: 7.0000 - val_tn: 493.0000 - val_fn: 42.0000 - val_precision: 0.9849 - val_recall: 0.9160 - val_auc: 0.9928 - val_prc: 0.9926
# Epoch 18/30
# 125/125 [==============================] - 31s 244ms/step - loss: 0.1224 - acc: 0.9805 - Brier score: 0.0166 - tp: 1952.0000 - fp: 30.0000 - tn: 1970.0000 - fn: 48.0000 - precision: 0.9849 - recall: 0.9760 - auc: 0.9983 - prc: 0.9984 - val_loss: 0.1318 - val_acc: 0.9790 - val_Brier score: 0.0192 - val_tp: 492.0000 - val_fp: 13.0000 - val_tn: 487.0000 - val_fn: 8.0000 - val_precision: 0.9743 - val_recall: 0.9840 - val_auc: 0.9972 - val_prc: 0.9971
# Epoch 19/30
# 125/125 [==============================] - 31s 242ms/step - loss: 0.1196 - acc: 0.9822 - Brier score: 0.0155 - tp: 1960.0000 - fp: 31.0000 - tn: 1969.0000 - fn: 40.0000 - precision: 0.9844 - recall: 0.9800 - auc: 0.9984 - prc: 0.9985 - val_loss: 0.1559 - val_acc: 0.9680 - val_Brier score: 0.0260 - val_tp: 484.0000 - val_fp: 16.0000 - val_tn: 484.0000 - val_fn: 16.0000 - val_precision: 0.9680 - val_recall: 0.9680 - val_auc: 0.9932 - val_prc: 0.9920
# Epoch 20/30
# 125/125 [==============================] - 31s 244ms/step - loss: 0.1109 - acc: 0.9858 - Brier score: 0.0125 - tp: 1961.0000 - fp: 18.0000 - tn: 1982.0000 - fn: 39.0000 - precision: 0.9909 - recall: 0.9805 - auc: 0.9987 - prc: 0.9989 - val_loss: 0.1337 - val_acc: 0.9750 - val_Brier score: 0.0209 - val_tp: 491.0000 - val_fp: 16.0000 - val_tn: 484.0000 - val_fn: 9.0000 - val_precision: 0.9684 - val_recall: 0.9820 - val_auc: 0.9964 - val_prc: 0.9964
# Epoch 21/30
# 125/125 [==============================] - 30s 243ms/step - loss: 0.1242 - acc: 0.9762 - Brier score: 0.0167 - tp: 1943.0000 - fp: 38.0000 - tn: 1962.0000 - fn: 57.0000 - precision: 0.9808 - recall: 0.9715 - auc: 0.9982 - prc: 0.9982 - val_loss: 0.1435 - val_acc: 0.9750 - val_Brier score: 0.0212 - val_tp: 487.0000 - val_fp: 12.0000 - val_tn: 488.0000 - val_fn: 13.0000 - val_precision: 0.9760 - val_recall: 0.9740 - val_auc: 0.9950 - val_prc: 0.9955
# Epoch 22/30
# 125/125 [==============================] - 31s 245ms/step - loss: 0.1155 - acc: 0.9837 - Brier score: 0.0144 - tp: 1960.0000 - fp: 25.0000 - tn: 1975.0000 - fn: 40.0000 - precision: 0.9874 - recall: 0.9800 - auc: 0.9986 - prc: 0.9987 - val_loss: 0.1426 - val_acc: 0.9710 - val_Brier score: 0.0224 - val_tp: 481.0000 - val_fp: 10.0000 - val_tn: 490.0000 - val_fn: 19.0000 - val_precision: 0.9796 - val_recall: 0.9620 - val_auc: 0.9967 - val_prc: 0.9966
# Epoch 23/30
# 125/125 [==============================] - 31s 243ms/step - loss: 0.1164 - acc: 0.9827 - Brier score: 0.0141 - tp: 1956.0000 - fp: 25.0000 - tn: 1975.0000 - fn: 44.0000 - precision: 0.9874 - recall: 0.9780 - auc: 0.9987 - prc: 0.9988 - val_loss: 0.1574 - val_acc: 0.9710 - val_Brier score: 0.0240 - val_tp: 489.0000 - val_fp: 18.0000 - val_tn: 482.0000 - val_fn: 11.0000 - val_precision: 0.9645 - val_recall: 0.9780 - val_auc: 0.9959 - val_prc: 0.9957
# Epoch 24/30
# 125/125 [==============================] - 30s 243ms/step - loss: 0.1152 - acc: 0.9862 - Brier score: 0.0134 - tp: 1967.0000 - fp: 22.0000 - tn: 1978.0000 - fn: 33.0000 - precision: 0.9889 - recall: 0.9835 - auc: 0.9989 - prc: 0.9989 - val_loss: 0.1866 - val_acc: 0.9500 - val_Brier score: 0.0346 - val_tp: 454.0000 - val_fp: 4.0000 - val_tn: 496.0000 - val_fn: 46.0000 - val_precision: 0.9913 - val_recall: 0.9080 - val_auc: 0.9955 - val_prc: 0.9961
# Epoch 25/30
# 125/125 [==============================] - 31s 246ms/step - loss: 0.1064 - acc: 0.9850 - Brier score: 0.0115 - tp: 1963.0000 - fp: 23.0000 - tn: 1977.0000 - fn: 37.0000 - precision: 0.9884 - recall: 0.9815 - auc: 0.9992 - prc: 0.9992 - val_loss: 0.1434 - val_acc: 0.9740 - val_Brier score: 0.0218 - val_tp: 484.0000 - val_fp: 10.0000 - val_tn: 490.0000 - val_fn: 16.0000 - val_precision: 0.9798 - val_recall: 0.9680 - val_auc: 0.9953 - val_prc: 0.9938
# Epoch 26/30
# 125/125 [==============================] - 30s 243ms/step - loss: 0.1163 - acc: 0.9820 - Brier score: 0.0139 - tp: 1954.0000 - fp: 26.0000 - tn: 1974.0000 - fn: 46.0000 - precision: 0.9869 - recall: 0.9770 - auc: 0.9987 - prc: 0.9987 - val_loss: 0.1437 - val_acc: 0.9750 - val_Brier score: 0.0216 - val_tp: 489.0000 - val_fp: 14.0000 - val_tn: 486.0000 - val_fn: 11.0000 - val_precision: 0.9722 - val_recall: 0.9780 - val_auc: 0.9953 - val_prc: 0.9940
# Epoch 27/30
# 125/125 [==============================] - 31s 245ms/step - loss: 0.1094 - acc: 0.9843 - Brier score: 0.0120 - tp: 1964.0000 - fp: 27.0000 - tn: 1973.0000 - fn: 36.0000 - precision: 0.9864 - recall: 0.9820 - auc: 0.9991 - prc: 0.9991 - val_loss: 0.1633 - val_acc: 0.9650 - val_Brier score: 0.0272 - val_tp: 481.0000 - val_fp: 16.0000 - val_tn: 484.0000 - val_fn: 19.0000 - val_precision: 0.9678 - val_recall: 0.9620 - val_auc: 0.9933 - val_prc: 0.9919
# Epoch 28/30
# 125/125 [==============================] - 31s 244ms/step - loss: 0.1096 - acc: 0.9865 - Brier score: 0.0118 - tp: 1970.0000 - fp: 24.0000 - tn: 1976.0000 - fn: 30.0000 - precision: 0.9880 - recall: 0.9850 - auc: 0.9990 - prc: 0.9990 - val_loss: 0.1497 - val_acc: 0.9690 - val_Brier score: 0.0243 - val_tp: 484.0000 - val_fp: 15.0000 - val_tn: 485.0000 - val_fn: 16.0000 - val_precision: 0.9699 - val_recall: 0.9680 - val_auc: 0.9944 - val_prc: 0.9931

# %%
plot_metrics(cnn_history, l2_history, legend1='CNN Train', legend2='CNN Val', legend3='L2 Train', legend4='L2 Val')

# %% [markdown]
# The addition of l2 regularizer did lower the overfitting but at the cost of `loss`, `precision`, and `acc`. Perhaps increasing the epoch and allowing the model to learn will fix the volatility of the metrics.
# <br>
# <br>Regardless, we will obtain the confusion matrix and scores of the new model:

# %%
l2_y_hat = predict(test_generator, l2_model)
# Out:
# 20/20 [==============================] - 5s 220ms/step

# %%
cf_matrix(l2_y_hat)

# %%
print_metrics(test_labels, l2_y_hat)
# Out:
# Precision Score: 0.78125
# Recall Score: 0.9615384615384616
# Accuracy Score: 0.8076923076923077
# F1 Score: 0.8620689655172413

# %% [markdown]
# Adding a ridge regression did reduce overfitting but with a major cost to both precision and accuracy of the model. To determine the best lambda value for the ridge regression, we can input a list of lambda values for `regularizer.l2()`, and create a `GridSearchCV` with a `param_grid` containing the list of lambda values. However, the computational power needed exceeds my current resources.

# %% [markdown]
# ### Adding a dropout layer to combat overfitting
# Another way to lower overfitting is by adding a `Dropout()` layer. This layer drops some of the nodes within the neural network before moving to the next. The best float value for the dropout layer can be found the same way as the lambda value for ridge regression.

# %%
from keras.layers import Dropout

# %%
dropout_model = Sequential()

dropout_model.add(Conv2D(64, kernel_size=(3,3), activation='relu',input_shape=(256,256,3)))
dropout_model.add(MaxPooling2D(2,2))

dropout_model.add(Flatten())

dropout_model.add(Dense(64, activation='relu'))
dropout_model.add(Dropout(0.3))
# added dropout layer with a 30% drop rate
dropout_model.add(Dense(1, activation='sigmoid'))

dropout_model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=metrics)


dropout_history = dropout_model.fit(balanced_train_generator,
          steps_per_epoch=int(np.ceil(4000/batch_size)),
          epochs=30,
          validation_data=balanced_validation_generator,
          validation_steps=int(np.ceil(1000/batch_size)),
          callbacks=[early_stop])
# Out:
# Epoch 1/30
# 125/125 [==============================] - 32s 249ms/step - loss: 1.2298 - acc: 0.7588 - Brier score: 0.1482 - tp: 1878.0000 - fp: 374.0000 - tn: 2126.0000 - fn: 622.0000 - precision: 0.8339 - recall: 0.7512 - auc: 0.8653 - prc: 0.8450 - val_loss: 0.2054 - val_acc: 0.9380 - val_Brier score: 0.0536 - val_tp: 470.0000 - val_fp: 32.0000 - val_tn: 468.0000 - val_fn: 30.0000 - val_precision: 0.9363 - val_recall: 0.9400 - val_auc: 0.9870 - val_prc: 0.9882
# Epoch 2/30
# 125/125 [==============================] - 31s 245ms/step - loss: 0.2705 - acc: 0.8992 - Brier score: 0.0812 - tp: 1758.0000 - fp: 161.0000 - tn: 1839.0000 - fn: 242.0000 - precision: 0.9161 - recall: 0.8790 - auc: 0.9597 - prc: 0.9648 - val_loss: 0.1529 - val_acc: 0.9460 - val_Brier score: 0.0406 - val_tp: 453.0000 - val_fp: 7.0000 - val_tn: 493.0000 - val_fn: 47.0000 - val_precision: 0.9848 - val_recall: 0.9060 - val_auc: 0.9913 - val_prc: 0.9918
# Epoch 3/30
# 125/125 [==============================] - 30s 243ms/step - loss: 0.2108 - acc: 0.9215 - Brier score: 0.0610 - tp: 1803.0000 - fp: 117.0000 - tn: 1883.0000 - fn: 197.0000 - precision: 0.9391 - recall: 0.9015 - auc: 0.9745 - prc: 0.9779 - val_loss: 0.1586 - val_acc: 0.9620 - val_Brier score: 0.0388 - val_tp: 480.0000 - val_fp: 18.0000 - val_tn: 482.0000 - val_fn: 20.0000 - val_precision: 0.9639 - val_recall: 0.9600 - val_auc: 0.9914 - val_prc: 0.9919
# Epoch 4/30
# 125/125 [==============================] - 30s 243ms/step - loss: 0.1574 - acc: 0.9410 - Brier score: 0.0456 - tp: 1853.0000 - fp: 89.0000 - tn: 1911.0000 - fn: 147.0000 - precision: 0.9542 - recall: 0.9265 - auc: 0.9873 - prc: 0.9885 - val_loss: 0.0972 - val_acc: 0.9690 - val_Brier score: 0.0252 - val_tp: 480.0000 - val_fp: 11.0000 - val_tn: 489.0000 - val_fn: 20.0000 - val_precision: 0.9776 - val_recall: 0.9600 - val_auc: 0.9938 - val_prc: 0.9929
# Epoch 5/30
# 125/125 [==============================] - 31s 245ms/step - loss: 0.1338 - acc: 0.9498 - Brier score: 0.0392 - tp: 1893.0000 - fp: 94.0000 - tn: 1906.0000 - fn: 107.0000 - precision: 0.9527 - recall: 0.9465 - auc: 0.9904 - prc: 0.9912 - val_loss: 0.1438 - val_acc: 0.9550 - val_Brier score: 0.0381 - val_tp: 488.0000 - val_fp: 33.0000 - val_tn: 467.0000 - val_fn: 12.0000 - val_precision: 0.9367 - val_recall: 0.9760 - val_auc: 0.9932 - val_prc: 0.9924
# Epoch 6/30
# 125/125 [==============================] - 31s 244ms/step - loss: 0.1160 - acc: 0.9565 - Brier score: 0.0343 - tp: 1904.0000 - fp: 78.0000 - tn: 1922.0000 - fn: 96.0000 - precision: 0.9606 - recall: 0.9520 - auc: 0.9929 - prc: 0.9933 - val_loss: 0.1093 - val_acc: 0.9640 - val_Brier score: 0.0290 - val_tp: 471.0000 - val_fp: 7.0000 - val_tn: 493.0000 - val_fn: 29.0000 - val_precision: 0.9854 - val_recall: 0.9420 - val_auc: 0.9913 - val_prc: 0.9915
# Epoch 7/30
# 125/125 [==============================] - 30s 243ms/step - loss: 0.0990 - acc: 0.9650 - Brier score: 0.0288 - tp: 1923.0000 - fp: 63.0000 - tn: 1937.0000 - fn: 77.0000 - precision: 0.9683 - recall: 0.9615 - auc: 0.9949 - prc: 0.9952 - val_loss: 0.1189 - val_acc: 0.9580 - val_Brier score: 0.0310 - val_tp: 490.0000 - val_fp: 32.0000 - val_tn: 468.0000 - val_fn: 10.0000 - val_precision: 0.9387 - val_recall: 0.9800 - val_auc: 0.9931 - val_prc: 0.9930
# Epoch 8/30
# 125/125 [==============================] - 30s 240ms/step - loss: 0.0855 - acc: 0.9680 - Brier score: 0.0244 - tp: 1944.0000 - fp: 72.0000 - tn: 1928.0000 - fn: 56.0000 - precision: 0.9643 - recall: 0.9720 - auc: 0.9965 - prc: 0.9966 - val_loss: 0.0861 - val_acc: 0.9720 - val_Brier score: 0.0217 - val_tp: 484.0000 - val_fp: 12.0000 - val_tn: 488.0000 - val_fn: 16.0000 - val_precision: 0.9758 - val_recall: 0.9680 - val_auc: 0.9939 - val_prc: 0.9935
# Epoch 9/30
# 125/125 [==============================] - 30s 239ms/step - loss: 0.0711 - acc: 0.9703 - Brier score: 0.0204 - tp: 1952.0000 - fp: 71.0000 - tn: 1929.0000 - fn: 48.0000 - precision: 0.9649 - recall: 0.9760 - auc: 0.9974 - prc: 0.9975 - val_loss: 0.1298 - val_acc: 0.9550 - val_Brier score: 0.0343 - val_tp: 493.0000 - val_fp: 38.0000 - val_tn: 462.0000 - val_fn: 7.0000 - val_precision: 0.9284 - val_recall: 0.9860 - val_auc: 0.9939 - val_prc: 0.9937
# Epoch 10/30
# 125/125 [==============================] - 30s 242ms/step - loss: 0.0592 - acc: 0.9725 - Brier score: 0.0161 - tp: 1957.0000 - fp: 67.0000 - tn: 1933.0000 - fn: 43.0000 - precision: 0.9669 - recall: 0.9785 - auc: 0.9978 - prc: 0.9973 - val_loss: 0.1068 - val_acc: 0.9660 - val_Brier score: 0.0255 - val_tp: 489.0000 - val_fp: 23.0000 - val_tn: 477.0000 - val_fn: 11.0000 - val_precision: 0.9551 - val_recall: 0.9780 - val_auc: 0.9919 - val_prc: 0.9913
# Epoch 11/30
# 125/125 [==============================] - 30s 240ms/step - loss: 0.0449 - acc: 0.9758 - Brier score: 0.0125 - tp: 1973.0000 - fp: 70.0000 - tn: 1930.0000 - fn: 27.0000 - precision: 0.9657 - recall: 0.9865 - auc: 0.9990 - prc: 0.9990 - val_loss: 0.0978 - val_acc: 0.9690 - val_Brier score: 0.0236 - val_tp: 486.0000 - val_fp: 17.0000 - val_tn: 483.0000 - val_fn: 14.0000 - val_precision: 0.9662 - val_recall: 0.9720 - val_auc: 0.9919 - val_prc: 0.9912
# Epoch 12/30
# 125/125 [==============================] - 30s 239ms/step - loss: 0.0337 - acc: 0.9795 - Brier score: 0.0094 - tp: 1983.0000 - fp: 65.0000 - tn: 1935.0000 - fn: 17.0000 - precision: 0.9683 - recall: 0.9915 - auc: 0.9995 - prc: 0.9995 - val_loss: 0.1337 - val_acc: 0.9660 - val_Brier score: 0.0277 - val_tp: 493.0000 - val_fp: 27.0000 - val_tn: 473.0000 - val_fn: 7.0000 - val_precision: 0.9481 - val_recall: 0.9860 - val_auc: 0.9888 - val_prc: 0.9828
# Epoch 13/30
# 125/125 [==============================] - 30s 239ms/step - loss: 0.0285 - acc: 0.9868 - Brier score: 0.0081 - tp: 1985.0000 - fp: 38.0000 - tn: 1962.0000 - fn: 15.0000 - precision: 0.9812 - recall: 0.9925 - auc: 0.9997 - prc: 0.9997 - val_loss: 0.1182 - val_acc: 0.9680 - val_Brier score: 0.0239 - val_tp: 491.0000 - val_fp: 23.0000 - val_tn: 477.0000 - val_fn: 9.0000 - val_precision: 0.9553 - val_recall: 0.9820 - val_auc: 0.9899 - val_prc: 0.9847
# Epoch 14/30
# 125/125 [==============================] - 31s 243ms/step - loss: 0.0262 - acc: 0.9923 - Brier score: 0.0072 - tp: 1984.0000 - fp: 15.0000 - tn: 1985.0000 - fn: 16.0000 - precision: 0.9925 - recall: 0.9920 - auc: 0.9997 - prc: 0.9997 - val_loss: 0.1203 - val_acc: 0.9750 - val_Brier score: 0.0226 - val_tp: 484.0000 - val_fp: 9.0000 - val_tn: 491.0000 - val_fn: 16.0000 - val_precision: 0.9817 - val_recall: 0.9680 - val_auc: 0.9906 - val_prc: 0.9891
# Epoch 15/30
# 125/125 [==============================] - 30s 242ms/step - loss: 0.0325 - acc: 0.9885 - Brier score: 0.0098 - tp: 1974.0000 - fp: 20.0000 - tn: 1980.0000 - fn: 26.0000 - precision: 0.9900 - recall: 0.9870 - auc: 0.9995 - prc: 0.9995 - val_loss: 0.1048 - val_acc: 0.9690 - val_Brier score: 0.0233 - val_tp: 488.0000 - val_fp: 19.0000 - val_tn: 481.0000 - val_fn: 12.0000 - val_precision: 0.9625 - val_recall: 0.9760 - val_auc: 0.9917 - val_prc: 0.9897
# Epoch 16/30
# 125/125 [==============================] - 30s 240ms/step - loss: 0.0318 - acc: 0.9898 - Brier score: 0.0090 - tp: 1975.0000 - fp: 16.0000 - tn: 1984.0000 - fn: 25.0000 - precision: 0.9920 - recall: 0.9875 - auc: 0.9995 - prc: 0.9996 - val_loss: 0.1111 - val_acc: 0.9700 - val_Brier score: 0.0235 - val_tp: 479.0000 - val_fp: 9.0000 - val_tn: 491.0000 - val_fn: 21.0000 - val_precision: 0.9816 - val_recall: 0.9580 - val_auc: 0.9936 - val_prc: 0.9938
# Epoch 17/30
# 125/125 [==============================] - 30s 240ms/step - loss: 0.0264 - acc: 0.9923 - Brier score: 0.0068 - tp: 1980.0000 - fp: 11.0000 - tn: 1989.0000 - fn: 20.0000 - precision: 0.9945 - recall: 0.9900 - auc: 0.9992 - prc: 0.9987 - val_loss: 0.1351 - val_acc: 0.9690 - val_Brier score: 0.0255 - val_tp: 492.0000 - val_fp: 23.0000 - val_tn: 477.0000 - val_fn: 8.0000 - val_precision: 0.9553 - val_recall: 0.9840 - val_auc: 0.9888 - val_prc: 0.9841
# Epoch 18/30
# 125/125 [==============================] - 30s 238ms/step - loss: 0.0263 - acc: 0.9908 - Brier score: 0.0078 - tp: 1974.0000 - fp: 11.0000 - tn: 1989.0000 - fn: 26.0000 - precision: 0.9945 - recall: 0.9870 - auc: 0.9996 - prc: 0.9996 - val_loss: 0.1187 - val_acc: 0.9760 - val_Brier score: 0.0219 - val_tp: 490.0000 - val_fp: 14.0000 - val_tn: 486.0000 - val_fn: 10.0000 - val_precision: 0.9722 - val_recall: 0.9800 - val_auc: 0.9905 - val_prc: 0.9879

# %%
plot_metrics(l2_history, dropout_history, legend1='L2 Train', legend2='L2 Val', legend3='Dropout Train', legend4='Dropout Val')

# %% [markdown]
# Using a dropout layer instead of ridge regression yielded more overfitting, therefore we will integrate the ridge regression to future models.

# %% [markdown]
# ## More layers
# Adding more layers allows the model to learn more complex tasks. If the data has greater complexity and dimensionality, multiple hidden layers should be incorporated. However, the performance may suffer if there is an insufficient amount of training data. We are only working with 5000 images, therefore multiple layers may yield poorer results.

# %%
layers_model = Sequential()

layers_model.add(Conv2D(64, kernel_size=(3,3), activation='relu',input_shape=(256,256,3)))
layers_model.add(MaxPooling2D((2,2), strides=2))

layers_model.add(Flatten())

layers_model.add(Dense(64, kernel_regularizer=regularizers.l2(0.0005), activation='relu'))

layers_model.add(Dense(128, kernel_regularizer=regularizers.l2(0.0005), activation='relu'))

layers_model.add(Dense(128, kernel_regularizer=regularizers.l2(0.0005), activation='relu'))

layers_model.add(Dense(1, activation='sigmoid'))

layers_model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=metrics)

layers_history = layers_model.fit(balanced_train_generator,
          steps_per_epoch=int(np.ceil(4000/batch_size)),
          epochs=30,
          validation_data=balanced_validation_generator,
          validation_steps=int(np.ceil(1000/batch_size)),
          callbacks=[early_stop])
# Out:
# Epoch 1/30
# 125/125 [==============================] - 32s 246ms/step - loss: 0.9532 - acc: 0.8290 - Brier score: 0.1136 - tp: 2073.0000 - fp: 281.0000 - tn: 2219.0000 - fn: 427.0000 - precision: 0.8806 - recall: 0.8292 - auc: 0.9120 - prc: 0.9052 - val_loss: 0.4204 - val_acc: 0.9230 - val_Brier score: 0.0521 - val_tp: 432.0000 - val_fp: 9.0000 - val_tn: 491.0000 - val_fn: 68.0000 - val_precision: 0.9796 - val_recall: 0.8640 - val_auc: 0.9889 - val_prc: 0.9894
# Epoch 2/30
# 125/125 [==============================] - 30s 237ms/step - loss: 0.3596 - acc: 0.9402 - Brier score: 0.0459 - tp: 1847.0000 - fp: 86.0000 - tn: 1914.0000 - fn: 153.0000 - precision: 0.9555 - recall: 0.9235 - auc: 0.9849 - prc: 0.9866 - val_loss: 0.4537 - val_acc: 0.8830 - val_Brier score: 0.0893 - val_tp: 497.0000 - val_fp: 114.0000 - val_tn: 386.0000 - val_fn: 3.0000 - val_precision: 0.8134 - val_recall: 0.9940 - val_auc: 0.9923 - val_prc: 0.9915
# Epoch 3/30
# 125/125 [==============================] - 30s 239ms/step - loss: 0.2901 - acc: 0.9548 - Brier score: 0.0353 - tp: 1899.0000 - fp: 80.0000 - tn: 1920.0000 - fn: 101.0000 - precision: 0.9596 - recall: 0.9495 - auc: 0.9906 - prc: 0.9914 - val_loss: 0.2550 - val_acc: 0.9650 - val_Brier score: 0.0282 - val_tp: 492.0000 - val_fp: 27.0000 - val_tn: 473.0000 - val_fn: 8.0000 - val_precision: 0.9480 - val_recall: 0.9840 - val_auc: 0.9953 - val_prc: 0.9952
# Epoch 4/30
# 125/125 [==============================] - 30s 239ms/step - loss: 0.2171 - acc: 0.9728 - Brier score: 0.0216 - tp: 1932.0000 - fp: 41.0000 - tn: 1959.0000 - fn: 68.0000 - precision: 0.9792 - recall: 0.9660 - auc: 0.9962 - prc: 0.9966 - val_loss: 0.2298 - val_acc: 0.9660 - val_Brier score: 0.0252 - val_tp: 488.0000 - val_fp: 22.0000 - val_tn: 478.0000 - val_fn: 12.0000 - val_precision: 0.9569 - val_recall: 0.9760 - val_auc: 0.9935 - val_prc: 0.9911
# Epoch 5/30
# 125/125 [==============================] - 30s 240ms/step - loss: 0.2001 - acc: 0.9732 - Brier score: 0.0190 - tp: 1941.0000 - fp: 48.0000 - tn: 1952.0000 - fn: 59.0000 - precision: 0.9759 - recall: 0.9705 - auc: 0.9972 - prc: 0.9973 - val_loss: 0.2733 - val_acc: 0.9500 - val_Brier score: 0.0356 - val_tp: 457.0000 - val_fp: 7.0000 - val_tn: 493.0000 - val_fn: 43.0000 - val_precision: 0.9849 - val_recall: 0.9140 - val_auc: 0.9907 - val_prc: 0.9901
# Epoch 6/30
# 125/125 [==============================] - 30s 238ms/step - loss: 0.1922 - acc: 0.9790 - Brier score: 0.0159 - tp: 1954.0000 - fp: 38.0000 - tn: 1962.0000 - fn: 46.0000 - precision: 0.9809 - recall: 0.9770 - auc: 0.9979 - prc: 0.9976 - val_loss: 0.2180 - val_acc: 0.9690 - val_Brier score: 0.0238 - val_tp: 482.0000 - val_fp: 13.0000 - val_tn: 487.0000 - val_fn: 18.0000 - val_precision: 0.9737 - val_recall: 0.9640 - val_auc: 0.9945 - val_prc: 0.9920
# Epoch 7/30
# 125/125 [==============================] - 30s 237ms/step - loss: 0.1631 - acc: 0.9850 - Brier score: 0.0110 - tp: 1965.0000 - fp: 25.0000 - tn: 1975.0000 - fn: 35.0000 - precision: 0.9874 - recall: 0.9825 - auc: 0.9987 - prc: 0.9989 - val_loss: 0.2255 - val_acc: 0.9700 - val_Brier score: 0.0255 - val_tp: 486.0000 - val_fp: 16.0000 - val_tn: 484.0000 - val_fn: 14.0000 - val_precision: 0.9681 - val_recall: 0.9720 - val_auc: 0.9939 - val_prc: 0.9914
# Epoch 8/30
# 125/125 [==============================] - 30s 237ms/step - loss: 0.1903 - acc: 0.9758 - Brier score: 0.0174 - tp: 1945.0000 - fp: 42.0000 - tn: 1958.0000 - fn: 55.0000 - precision: 0.9789 - recall: 0.9725 - auc: 0.9968 - prc: 0.9964 - val_loss: 0.4088 - val_acc: 0.8980 - val_Brier score: 0.0772 - val_tp: 496.0000 - val_fp: 98.0000 - val_tn: 402.0000 - val_fn: 4.0000 - val_precision: 0.8350 - val_recall: 0.9920 - val_auc: 0.9885 - val_prc: 0.9842
# Epoch 9/30
# 125/125 [==============================] - 30s 236ms/step - loss: 0.3470 - acc: 0.9463 - Brier score: 0.0408 - tp: 1883.0000 - fp: 98.0000 - tn: 1902.0000 - fn: 117.0000 - precision: 0.9505 - recall: 0.9415 - auc: 0.9867 - prc: 0.9882 - val_loss: 0.3676 - val_acc: 0.9400 - val_Brier score: 0.0461 - val_tp: 470.0000 - val_fp: 30.0000 - val_tn: 470.0000 - val_fn: 30.0000 - val_precision: 0.9400 - val_recall: 0.9400 - val_auc: 0.9828 - val_prc: 0.9857
# Epoch 10/30
# 125/125 [==============================] - 30s 235ms/step - loss: 0.2522 - acc: 0.9735 - Brier score: 0.0194 - tp: 1938.0000 - fp: 44.0000 - tn: 1956.0000 - fn: 62.0000 - precision: 0.9778 - recall: 0.9690 - auc: 0.9970 - prc: 0.9973 - val_loss: 0.2903 - val_acc: 0.9570 - val_Brier score: 0.0325 - val_tp: 480.0000 - val_fp: 23.0000 - val_tn: 477.0000 - val_fn: 20.0000 - val_precision: 0.9543 - val_recall: 0.9600 - val_auc: 0.9890 - val_prc: 0.9892
# Epoch 11/30
# 125/125 [==============================] - 30s 236ms/step - loss: 0.1816 - acc: 0.9887 - Brier score: 0.0097 - tp: 1972.0000 - fp: 17.0000 - tn: 1983.0000 - fn: 28.0000 - precision: 0.9915 - recall: 0.9860 - auc: 0.9990 - prc: 0.9991 - val_loss: 0.2734 - val_acc: 0.9490 - val_Brier score: 0.0361 - val_tp: 471.0000 - val_fp: 22.0000 - val_tn: 478.0000 - val_fn: 29.0000 - val_precision: 0.9554 - val_recall: 0.9420 - val_auc: 0.9864 - val_prc: 0.9879
# Epoch 12/30
# 125/125 [==============================] - 30s 237ms/step - loss: 0.1585 - acc: 0.9898 - Brier score: 0.0087 - tp: 1978.0000 - fp: 19.0000 - tn: 1981.0000 - fn: 22.0000 - precision: 0.9905 - recall: 0.9890 - auc: 0.9994 - prc: 0.9994 - val_loss: 0.2692 - val_acc: 0.9620 - val_Brier score: 0.0328 - val_tp: 471.0000 - val_fp: 9.0000 - val_tn: 491.0000 - val_fn: 29.0000 - val_precision: 0.9812 - val_recall: 0.9420 - val_auc: 0.9863 - val_prc: 0.9851
# Epoch 13/30
# 125/125 [==============================] - 30s 237ms/step - loss: 0.1269 - acc: 0.9970 - Brier score: 0.0032 - tp: 1992.0000 - fp: 4.0000 - tn: 1996.0000 - fn: 8.0000 - precision: 0.9980 - recall: 0.9960 - auc: 0.9999 - prc: 0.9999 - val_loss: 0.2536 - val_acc: 0.9620 - val_Brier score: 0.0321 - val_tp: 471.0000 - val_fp: 9.0000 - val_tn: 491.0000 - val_fn: 29.0000 - val_precision: 0.9812 - val_recall: 0.9420 - val_auc: 0.9837 - val_prc: 0.9851
# Epoch 14/30
# 125/125 [==============================] - 30s 238ms/step - loss: 0.1590 - acc: 0.9852 - Brier score: 0.0120 - tp: 1966.0000 - fp: 25.0000 - tn: 1975.0000 - fn: 34.0000 - precision: 0.9874 - recall: 0.9830 - auc: 0.9984 - prc: 0.9987 - val_loss: 0.3188 - val_acc: 0.9540 - val_Brier score: 0.0416 - val_tp: 471.0000 - val_fp: 17.0000 - val_tn: 483.0000 - val_fn: 29.0000 - val_precision: 0.9652 - val_recall: 0.9420 - val_auc: 0.9828 - val_prc: 0.9819
# Epoch 15/30
# 125/125 [==============================] - 30s 238ms/step - loss: 0.1904 - acc: 0.9820 - Brier score: 0.0137 - tp: 1959.0000 - fp: 31.0000 - tn: 1969.0000 - fn: 41.0000 - precision: 0.9844 - recall: 0.9795 - auc: 0.9980 - prc: 0.9979 - val_loss: 0.4059 - val_acc: 0.9080 - val_Brier score: 0.0740 - val_tp: 483.0000 - val_fp: 75.0000 - val_tn: 425.0000 - val_fn: 17.0000 - val_precision: 0.8656 - val_recall: 0.9660 - val_auc: 0.9771 - val_prc: 0.9750
# Epoch 16/30
# 125/125 [==============================] - 30s 238ms/step - loss: 0.1621 - acc: 0.9910 - Brier score: 0.0075 - tp: 1983.0000 - fp: 19.0000 - tn: 1981.0000 - fn: 17.0000 - precision: 0.9905 - recall: 0.9915 - auc: 0.9992 - prc: 0.9989 - val_loss: 0.2535 - val_acc: 0.9600 - val_Brier score: 0.0305 - val_tp: 479.0000 - val_fp: 19.0000 - val_tn: 481.0000 - val_fn: 21.0000 - val_precision: 0.9618 - val_recall: 0.9580 - val_auc: 0.9876 - val_prc: 0.9877

# %%
plot_metrics(layers_history, l2_history, legend1='Layers Train', legend2='Layers Val', legend3='L2 Train', legend4='L2 Val')

# %% [markdown]
# The metrics of both multilayered and `l2_model` performed pretty comparably. However, the differences between the loss metric is slightly higher for the multilayered model.

# %% [markdown]
# ## Save the best fit model
# The parameters of the model is observed and stored for future use. For this particular dataset, the `l2_model` yielded the best results.

# %%
l2_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 254, 254, 64)      1792
#
#  max_pooling2d_1 (MaxPooling  (None, 127, 127, 64)     0
#  2D)
#
#  flatten_2 (Flatten)         (None, 1032256)           0
#
#  dense_4 (Dense)             (None, 64)                66064448
#
#  dense_5 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 66,066,305
# Trainable params: 66,066,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
l2_model.save('normal_pneumonia_with_augmented_data.keras')

# %% [markdown]
# ## Using Vgg16 model to predict viral or bacterial pneumonia.
# Because the data also labels whether the pneumonia is viral or bacterial, we can maybe create a model that separates the two. Instead of creating a new model, we can use the Vgg16 model to predict the etiology of pneumonia. The layers of the Vgg16 model can be seen here: ![image.png](attachment:image.png)
# <br>The last layer will be changed to a dense layer with 1 output instead of 1000 because our outputs are binary. The preparation and results of the Vgg16 model is written [here](./Using%20the%20Vgg16%20model%20to%20separate%20pneumonia%20caused%20by%20virus%20and%20bacteria.ipynb).

# %% [markdown]
# ### Summary of the new Vgg16 model

# %% [markdown]
# ![image-3.png](attachment:image-3.png)
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# ### Results of the Vgg16 model
# | Metric| Value |
# |:-----------------|:------:|
# | Precision | 0.6012658227848101   |
# | Recall    | 0.6418918918918919    |
# | Accuracy  | 0.7025641025641025    |
# | F1 Score  | 0.6209150326797386    |

# %% [markdown]
# ## Conclusion
# ___
# #### Recommendation
# When integrating a ridge regression into our model, the `l2_model` is able to differentiate between patients with or without pneumonia decently. It has an accuracy score of around 81% while having a higher recall than precision score. This is preferred as we do not want to misdiagnose a patient who has pneumonia as being healthy. The `cnn_model` did return higher metrics than the `l2_model`, but the `cnn_model` experienced some overfitting. Therefore, it may not perform as well on a different test set and is omitted. These percentages may change as the code is rerun, but the recall seems to be consistently higher than the precision. We recommend the `l2_model` when predicting pneumonia from chest x-rays as it does a good job fitting the validation set while keeping accuracy and recall score relatively high. Further improvements to the model can be made but l2 regularizers should be implemented in `Dense()` layers.
# #### Vgg16 model cannot tell the difference between viral and bacterial pneumonia
# However, when trying to differentiate between viral and bacterial pneumonia, the model did not perform very well. This may be due to the images of the two classes being too similar. Perhaps with the inclusion of other symtoms, the model may return more accurate metrics. It could also be that the Vgg16 model is not very good at classifying these specific data and a new model should be constructed.
# #### An issue with class imbalances
# One major problem that we face in this project is the class imbalance issue. In an effort to preserve as much data as we can, we have created new images that are augmented from pre-existing images. This may be the reason why the recall score is higher than the precision. A better method may be just to undersample the majority class and apply an augmentation to the images in both classes.
# #### Using AI to address issues in healthcare
# According to [this article by the AHRQ](https://www.ahrq.gov/prevention/clinician/ahrq-works/burnout/index.html), around 50% of physicians experience burnout; with the ongoing shortage of doctors, this problem will only get worse. By applying the deep learning models in their healthcare programs, it may lessen the load on doctors and reduce burnout. In turn, more patients can be treated while improving patient-doctor dynamics.
